# %% [markdown]
# <a href="https://colab.research.google.com/github/Swastika-IT/yolodevs/blob/main/efvn4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3a0e85ae-f533-4b3e-82db-9d71a33b4e1a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a0e85ae-f533-4b3e-82db-9d71a33b4e1a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.0 MB/s eta 0:00:00
# ...

# %%
# !unzip -q ultralytics-env2.zip -d /content/

# %%
# %cd /content/ultralytics-env2/ultralytics-main
# Out:
# /content/ultralytics-env2/ultralytics-main

# %%
from ultralytics import YOLO

model = YOLO("ultralytics/cfg/models/26/yolo26_efficientnetv2s_nam.yaml")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Layer 0 | from=-1 | module=ConvBnAct | c2=24
# i = 0 ch = [3]
# Layer 1 | from=-1 | module=FusedMBConv | c2=24
# i = 1 ch = [24]
# Layer 2 | from=-1 | module=FusedMBConv | c2=48
# i = 2 ch = [24, 24]
# Layer 3 | from=-1 | module=FusedMBConv | c2=64
# i = 3 ch = [24, 24, 48]
# Layer 4 | from=-1 | module=NAM_MBConv | c2=128
# i = 4 ch = [24, 24, 48, 64]
# Layer 5 | from=-1 | module=NAM_MBConv | c2=160
# i = 5 ch = [24, 24, 48, 64, 128]
# Layer 6 | from=-1 | module=NAM_MBConv | c2=256
# i = 6 ch = [24, 24, 48, 64, 128, 160]
# Layer 7 | from=-1 | module=SPPF | c2=256
# i = 7 ch = [24, 24, 48, 64, 128, 160, 256]
# Layer 8 | from=-1 | module=ConvBnAct | c2=160
# ...

# %%
from google.colab import files

print("Please select the file to upload.")
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# Please select the file to upload.
#      <input type="file" id="files-f338b379-fb01-4e46-a799-31eb6062c0f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f338b379-fb01-4e46-a799-31eb6062c0f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import zipfile

with zipfile.ZipFile("Rice-Quality 3.v4i.yolov12-zip.zip", "r") as zip_ref:
    zip_ref.extractall("/content/")

# %%
model.train(
    data="/content/data.yaml",
    epochs=100
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.77 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import os

os.listdir("/content/ultralytics-env2/ultralytics-main/runs/detect/train-2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1998/908653464.py in <cell line: 0>()
#       1 import os
#       2
# ----> 3 os.listdir("/content/ultralytics-env2/ultralytics-main/runs/detect/train-2")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/ultralytics-env2/ultralytics-main/runs/detect/train-2'

# %%
import os

os.listdir("/content/runs/detect/predict")

# %%
metrics = model.val()
